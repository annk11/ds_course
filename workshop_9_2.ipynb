# %%
import pandas as pd
import urllib.request

# %%
url = 'https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook-Second-Edition/master/data/movie.csv'
filename = 'movie.csv'

urllib.request.urlretrieve(url, filename)
# Out:
# ('movie.csv', <http.client.HTTPMessage at 0x26b77f41f10>)

# %%
df = pd.read_csv('movie.csv')
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
print(f'The shape of data: {df.shape}')
# Out:
# The shape of data: (4916, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
#  13  cast_total_facebook_likes  4916 non-null   int64
#  14  actor_3_name               4893 non-null   object
#  15  facenumber_in_poster       4903 non-null   float64
#  16  plot_keywords              4764 non-null   object
#  17  movie_imdb_link            4916 non-null   object
#  18  num_user_for_reviews       4895 non-null   float64
#  19  language                   4902 non-null   object
#  20  country                    4911 non-null   object
#  21  content_rating             4616 non-null   object
#  22  budget                     4432 non-null   float64
#  23  title_year                 4810 non-null   float64
#  24  actor_2_facebook_likes     4903 non-null   float64
#  25  imdb_score                 4916 non-null   float64
#  26  aspect_ratio               4590 non-null   float64
#  27  movie_facebook_likes       4916 non-null   int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB

# %%
 df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                132.000000              607.000000  5.019656e+06
# 50%                366.000000              982.000000  2.504396e+07
# 75%                633.000000            11000.000000  6.110841e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     4.916000e+03                4916.000000           4903.000000
# mean      8.264492e+04                9579.815907              1.377320
# std       1.383222e+05               18164.316990              2.023826
# min       5.000000e+00                   0.000000              0.000000
# 25%       8.361750e+03                1394.750000              0.000000
# 50%       3.313250e+04                3049.000000              1.000000
# 75%       9.377275e+04               13616.750000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           4895.000000  4.432000e+03  4810.000000
# mean             267.668846  3.654749e+07  2002.447609
# std              372.934839  1.002427e+08    12.453977
# min                1.000000  2.180000e+02  1916.000000
# 25%               64.000000  6.000000e+06  1999.000000
# 50%              153.000000  1.985000e+07  2005.000000
# 75%              320.500000  4.300000e+07  2011.000000
# max             5060.000000  4.200000e+09  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             4903.000000  4916.000000   4590.000000           4916.000000
# mean              1621.923516     6.437429      2.222349           7348.294142
# std               4011.299523     1.127802      1.402940          19206.016458
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                277.000000     5.800000      1.850000              0.000000
# 50%                593.000000     6.600000      2.350000            159.000000
# 75%                912.000000     7.200000      2.350000           2000.000000
# max             137000.000000     9.500000     16.000000         349000.000000

# %%
df.isna().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
# Select columns
df_clean = df[[
    'color', 'director_name', 'duration', 'gross', 'genres', 'country', 'budget', 'imdb_score', 'actor_1_name', 'title_year', 'movie_title'
]]

df_clean = df_clean.copy()

# %%
df_clean.color.value_counts()
# Out:
# color
# Color              4693
# Black and White     204
# Name: count, dtype: int64

# %%
print(f'Before .dropna():{df_clean.shape}')

df_clean = df_clean.dropna()
print(f'After .dropna():{df_clean.shape}')
# Out:
# Before .dropna():(4916, 11)
# After .dropna():(3783, 11)

# %%
df_clean = df_clean[df_clean.color == 'Color']
df_clean.shape
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 5       True
#         ...
# 4906    True
# 4907    True
# 4908    True
# 4910    True
# 4915    True
# Name: color, Length: 3655, dtype: bool

# %%
df_clean.sample(5)
# Out:
#       color     director_name  duration        gross  \
# 82    Color  Robert Stromberg      97.0  241407328.0
# 132   Color      Hoyt Yeatman      88.0  119420252.0
# 136   Color      Joe Johnston     119.0   61937495.0
# 2140  Color      Brian Levant      95.0   82301521.0
# 2036  Color       David Twohy     112.0   39235088.0
#
#                                                  genres country       budget  \
# 82              Action|Adventure|Family|Fantasy|Romance     USA  180000000.0
# 132   Action|Adventure|Animation|Comedy|Family|Fanta...     USA  150000000.0
# 136                       Drama|Fantasy|Horror|Thriller     USA  150000000.0
# 2140                    Adventure|Comedy|Family|Romance     USA   32000000.0
# 2036                                      Horror|Sci-Fi     USA   23000000.0
#
#       imdb_score         actor_1_name  title_year        movie_title
# 82           7.0  Angelina Jolie Pitt      2014.0         Maleficent
# 132          5.1         Kelli Garner      2009.0            G-Force
# 136          5.8      Anthony Hopkins      2010.0        The Wolfman
# 2140         4.6             Nia Long      2005.0  Are We There Yet?
# 2036         7.1           Vin Diesel      2000.0        Pitch Black

# %%
actor_counts = df_clean['actor_1_name'].value_counts()
actor_counts.head(10)
# Out:
# actor_1_name
# Robert De Niro       40
# Johnny Depp          33
# Nicolas Cage         30
# J.K. Simmons         29
# Matt Damon           28
# Denzel Washington    28
# Bruce Willis         27
# Robin Williams       26
# Robert Downey Jr.    25
# Harrison Ford        25
# Name: count, dtype: int64

# %%
import matplotlib

df_clean['title_year'].value_counts().sort_index().plot(kind='bar', figsize=(15, 5))
# Out:
# <Axes: xlabel='title_year'>

# %%
budget_by_country = df_clean.groupby('country')['gross'].mean()

budget_by_country.sort_values(ascending=False)[:10]
# Out:
# country
# New Zealand     9.578414e+07
# Taiwan          6.434068e+07
# South Africa    5.782560e+07
# Peru            5.736258e+07
# USA             5.719592e+07
# Australia       3.942044e+07
# Japan           3.676716e+07
# UK              3.349275e+07
# Germany         3.082014e+07
# Canada          2.677290e+07
# Name: gross, dtype: float64

# %%
groped_data = df_clean.groupby(['title_year', 'country'])['imdb_score'].mean()

top_country_each_year = groped_data.groupby('title_year').apply(lambda x: x.idxmax()[1])

print(top_country_each_year.iloc[-20:])
# Out:
# title_year
# 1997.0              Iran
# 1998.0           Denmark
# 1999.0    Czech Republic
# 2000.0            Mexico
# 2001.0       New Zealand
# 2002.0            Brazil
# 2003.0       South Korea
# 2004.0       South Korea
# 2005.0       South Korea
# 2006.0             Spain
# 2007.0            Brazil
# 2008.0            Israel
# 2009.0         Argentina
# 2010.0             India
# 2011.0              Iran
# 2012.0           Denmark
# 2013.0             India
# 2014.0       New Zealand
# 2015.0             India
# 2016.0                UK
# Name: imdb_score, dtype: object

# %%
import matplotlib.pyplot as plt

plt.scatter(df_clean['imdb_score'], df_clean['gross'])
plt.ylabel('Gross')
plt.xlabel('IMDB score')
plt.show()

# %%
df_clean.sort_values('gross', ascending=False).head()
# Out:
#     color      director_name  duration        gross  \
# 0   Color      James Cameron     178.0  760505847.0
# 26  Color      James Cameron     194.0  658672302.0
# 29  Color    Colin Trevorrow     124.0  652177271.0
# 17  Color        Joss Whedon     173.0  623279547.0
# 66  Color  Christopher Nolan     152.0  533316061.0
#
#                               genres country       budget  imdb_score  \
# 0    Action|Adventure|Fantasy|Sci-Fi     USA  237000000.0         7.9
# 26                     Drama|Romance     USA  200000000.0         7.7
# 29  Action|Adventure|Sci-Fi|Thriller     USA  150000000.0         7.0
# 17           Action|Adventure|Sci-Fi     USA  220000000.0         8.1
# 66       Action|Crime|Drama|Thriller     USA  185000000.0         9.0
#
#            actor_1_name  title_year      movie_title
# 0           CCH Pounder      2009.0           Avatar
# 26    Leonardo DiCaprio      1997.0          Titanic
# 29  Bryce Dallas Howard      2015.0   Jurassic World
# 17      Chris Hemsworth      2012.0     The Avengers
# 66       Christian Bale      2008.0  The Dark Knight

# %%
df_clean['imdb_score_rounded'] = df_clean['imdb_score'].round()

df_clean[['imdb_score', 'imdb_score_rounded']].sample(5)
# Out:
#       imdb_score  imdb_score_rounded
# 1956         7.0                 7.0
# 2191         6.9                 7.0
# 4824         6.7                 7.0
# 735          4.4                 4.0
# 1032         6.9                 7.0

# %%
avg_gross_by_rating = df_clean.groupby('imdb_score_rounded')['gross'].mean()
avg_gross_by_rating
# Out:
# imdb_score_rounded
# 2.0    1.676042e+07
# 3.0    1.652262e+07
# 4.0    2.819435e+07
# 5.0    3.224518e+07
# 6.0    4.438782e+07
# 7.0    5.151024e+07
# 8.0    8.043655e+07
# 9.0    1.733000e+08
# Name: gross, dtype: float64

# %%
df_clean = df_clean.join(avg_gross_by_rating, on='imdb_score_rounded', rsuffix='_avg_for_rating')
df_clean.head()
# Out:
#    color      director_name  duration        gross  \
# 0  Color      James Cameron     178.0  760505847.0
# 1  Color     Gore Verbinski     169.0  309404152.0
# 2  Color         Sam Mendes     148.0  200074175.0
# 3  Color  Christopher Nolan     164.0  448130642.0
# 5  Color     Andrew Stanton     132.0   73058679.0
#
#                             genres country       budget  imdb_score  \
# 0  Action|Adventure|Fantasy|Sci-Fi     USA  237000000.0         7.9
# 1         Action|Adventure|Fantasy     USA  300000000.0         7.1
# 2        Action|Adventure|Thriller      UK  245000000.0         6.8
# 3                  Action|Thriller     USA  250000000.0         8.5
# 5          Action|Adventure|Sci-Fi     USA  263700000.0         6.6
#
#       actor_1_name  title_year                               movie_title  \
# 0      CCH Pounder      2009.0                                    Avatar
# 1      Johnny Depp      2007.0  Pirates of the Caribbean: At World's End
# 2  Christoph Waltz      2015.0                                   Spectre
# 3        Tom Hardy      2012.0                     The Dark Knight Rises
# 5     Daryl Sabara      2012.0                               John Carter
#
#    imdb_score_rounded  gross_avg_for_rating
# 0                 8.0          8.043655e+07
# 1                 7.0          5.151024e+07
# 2                 7.0          5.151024e+07
# 3                 8.0          8.043655e+07
# 5                 7.0          5.151024e+07

# %%
df_clean['gross_factor'] = df_clean['gross'] / df_clean['gross_avg_for_rating']

df_clean.sort_values('gross_factor', ascending=False).head(10)
# Out:
#      color    director_name  duration        gross  \
# 29   Color  Colin Trevorrow     124.0  652177271.0
# 237  Color     George Lucas     136.0  474544677.0
# 0    Color    James Cameron     178.0  760505847.0
# 624  Color      David Slade     124.0  300523113.0
# 917  Color      Chris Weitz     130.0  296623634.0
# 36   Color      Michael Bay     150.0  402076689.0
# 576  Color   Andrew Adamson      93.0  436471036.0
# 13   Color   Gore Verbinski     151.0  423032628.0
# 26   Color    James Cameron     194.0  658672302.0
# 32   Color      Shane Black     195.0  408992272.0
#
#                                                 genres country       budget  \
# 29                    Action|Adventure|Sci-Fi|Thriller     USA  150000000.0
# 237                    Action|Adventure|Fantasy|Sci-Fi     USA  115000000.0
# 0                      Action|Adventure|Fantasy|Sci-Fi     USA  237000000.0
# 624                    Adventure|Drama|Fantasy|Romance     USA   68000000.0
# 917                    Adventure|Drama|Fantasy|Romance     USA   50000000.0
# 36                             Action|Adventure|Sci-Fi     USA  200000000.0
# 576  Adventure|Animation|Comedy|Family|Fantasy|Romance     USA  150000000.0
# 13                            Action|Adventure|Fantasy     USA  225000000.0
# 26                                       Drama|Romance     USA  200000000.0
# 32                             Action|Adventure|Sci-Fi     USA  200000000.0
#
#      imdb_score         actor_1_name  title_year  \
# 29          7.0  Bryce Dallas Howard      2015.0
# 237         6.5      Natalie Portman      1999.0
# 0           7.9          CCH Pounder      2009.0
# 624         4.9     Robert Pattinson      2010.0
# 917         4.6     Robert Pattinson      2009.0
# 36          6.0      Glenn Morshower      2009.0
# 576         7.2       Rupert Everett      2004.0
# 13          7.3          Johnny Depp      2006.0
# 26          7.7    Leonardo DiCaprio      1997.0
# 32          7.2    Robert Downey Jr.      2013.0
#
#                                     movie_title  imdb_score_rounded  \
# 29                               Jurassic World                 7.0
# 237   Star Wars: Episode I - The Phantom Menace                 6.0
# 0                                        Avatar                 8.0
# 624                  The Twilight Saga: Eclipse                 5.0
# 917                 The Twilight Saga: New Moon                 5.0
# 36          Transformers: Revenge of the Fallen                 6.0
# 576                                     Shrek 2                 7.0
# 13   Pirates of the Caribbean: Dead Man's Chest                 7.0
# 26                                      Titanic                 8.0
# 32                                   Iron Man 3                 7.0
#
#      gross_avg_for_rating  gross_factor
# 29           5.151024e+07     12.661120
# 237          4.438782e+07     10.690877
# 0            8.043655e+07      9.454730
# 624          3.224518e+07      9.319940
# 917          3.224518e+07      9.199008
# 36           4.438782e+07      9.058267
# 576          5.151024e+07      8.473482
# 13           5.151024e+07      8.212593
# 26           8.043655e+07      8.188719
# 32           5.151024e+07      7.940019

# %%
df[(df.country == 'USA') & (df.title_year == 2008)]
# Out:
#                 color      director_name  num_critic_for_reviews  duration  \
# 16              Color     Andrew Adamson                   258.0     150.0
# 54              Color   Steven Spielberg                   470.0     122.0
# 58              Color     Andrew Stanton                   421.0      98.0
# 66              Color  Christopher Nolan                   645.0     152.0
# 69              Color        Jon Favreau                   486.0     126.0
# ...               ...                ...                     ...       ...
# 4757            Color  Rachel Goldenberg                     5.0      93.0
# 4785            Color      Justin Dillon                     7.0      86.0
# 4789            Color        Jay Duplass                    93.0      84.0
# 4793            Color     Marianna Palka                    38.0      86.0
# 4797  Black and White       James Kerwin                    25.0      89.0
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# 16                       80.0                   201.0  Pierfrancesco Favino
# 54                    14000.0                  1000.0          Ray Winstone
# 58                      475.0                   522.0          Fred Willard
# 66                    22000.0                 11000.0          Heath Ledger
# 69                     4000.0                  4000.0          Jeff Bridges
# ...                       ...                     ...                   ...
# 4757                      7.0                    73.0           Mark Hengst
# 4785                      0.0                    15.0   Natasha Bedingfield
# 4789                    157.0                    98.0      Jennifer Lafleur
# 4793                    123.0                   782.0          Martin Starr
# 4797                      0.0                    31.0       Chase Masterson
#
#       actor_1_facebook_likes        gross                              genres  \
# 16                   22000.0  141614023.0     Action|Adventure|Family|Fantasy
# 54                   11000.0  317011114.0            Action|Adventure|Fantasy
# 58                    1000.0  223806889.0   Adventure|Animation|Family|Sci-Fi
# 66                   23000.0  533316061.0         Action|Crime|Drama|Thriller
# 69                   21000.0  318298180.0             Action|Adventure|Sci-Fi
# ...                      ...          ...                                 ...
# 4757                   349.0          NaN                       Drama|Musical
# 4785                   178.0     215185.0           Documentary|History|Music
# 4789                   962.0     140016.0         Comedy|Drama|Horror|Romance
# 4793                  3000.0      15542.0                Comedy|Drama|Romance
# 4797                   236.0          NaN  Drama|Music|Mystery|Romance|Sci-Fi
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 16    ...                438.0  English      USA              PG  225000000.0
# 54    ...               2054.0  English      USA           PG-13  185000000.0
# 58    ...               1043.0  English      USA               G  180000000.0
# 66    ...               4667.0  English      USA           PG-13  185000000.0
# 69    ...               1055.0  English      USA           PG-13  140000000.0
# ...   ...                  ...      ...      ...             ...          ...
# 4757  ...                 18.0  English      USA               G          NaN
# 4785  ...                  2.0  English      USA           PG-13     200000.0
# 4789  ...                 40.0  English      USA               R          NaN
# 4793  ...                 51.0  English      USA               R          NaN
# 4797  ...                 10.0  English      USA              PG    2500000.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 16        2008.0                  216.0        6.6          2.35
# 54        2008.0                 1000.0        6.2          2.35
# 58        2008.0                  729.0        8.4          2.35
# 66        2008.0                13000.0        9.0          2.35
# 69        2008.0                12000.0        7.9          2.35
# ...          ...                    ...        ...           ...
# 4757      2008.0                  168.0        2.5          1.85
# 4785      2008.0                   58.0        7.5           NaN
# 4789      2008.0                  873.0        6.0          1.85
# 4793      2008.0                  985.0        6.5          1.85
# 4797      2008.0                  189.0        5.4          1.78
#
#      movie_facebook_likes
# 16                      0
# 54                   5000
# 58                  16000
# 66                  37000
# 69                  10000
# ...                   ...
# 4757                  777
# 4785                   26
# 4789                  443
# 4793                    0
# 4797                   83
#
# [161 rows x 28 columns]
